# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravindkumar-wp/2025-2026-4122-Aravindkumar-AI-B-DS/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#list
a=[10,20,30]
b=[1,2,3]
print("list 1:",a)
print("list 2:",b)
a.append(40)
a.extend([50,60])
print("updated list :",a)
# Out:
# list 1: [10, 20, 30]
# list 2: [1, 2, 3]
# updated list : [10, 20, 30, 40, 50, 60]
