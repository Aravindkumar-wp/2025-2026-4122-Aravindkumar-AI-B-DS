# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravindkumar-wp/2025-2026-4122-Aravindkumar-AI-B-DS/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = {
    "name": "Aravind",
    "roll": 122,
    "branch": "CSA"
}
print(student)
# Out:
# {'name': 'Aravind', 'roll': 122, 'branch': 'CSA'}

# %%
print(student["name"])
print(student.get("roll"))
# Out:
# Aravind
# 122

# %%
student["college"] = "Methodist"
student["roll"] = 4122
print(student)
# Out:
# {'name': 'Aravind', 'roll': 4122, 'branch': 'CSA', 'college': 'Methodist'}

# %%
print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['name', 'roll', 'branch', 'college'])
# dict_values(['Aravind', 4122, 'CSA', 'Methodist'])
# dict_items([('name', 'Aravind'), ('roll', 4122), ('branch', 'CSA'), ('college', 'Methodist')])
