# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravindkumar-wp/2025-2026-4122-Aravindkumar-AI-B-DS/blob/main/week-5/standardization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data = np.array([10, 20, 30, 40, 50])
mean = np.mean(data)
std = np.std(data)
standardized_data = (data - mean) / std
print("Original Data:", data)
print("Standardized Data:", standardized_data)
# Out:
# Original Data: [10 20 30 40 50]
# Standardized Data: [-1.41421356 -0.70710678  0.          0.70710678  1.41421356]
