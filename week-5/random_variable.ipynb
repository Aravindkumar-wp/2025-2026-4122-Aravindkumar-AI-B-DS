# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravindkumar-wp/2025-2026-4122-Aravindkumar-AI-B-DS/blob/main/week-5/random_variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
mean = 0
std_dev = 1
random_variable = np.random.normal(mean, std_dev, 10)
print("Random Variable Values:")
print(random_variable)
# Out:
# Random Variable Values:
# [ 0.78851561  1.14309807 -1.47251045 -0.96874448  0.43001818 -0.22154674
#  -0.25250782  0.95801264  0.05696657  0.3651196 ]
