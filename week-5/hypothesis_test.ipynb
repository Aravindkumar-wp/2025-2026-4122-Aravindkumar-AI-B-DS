# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravindkumar-wp/2025-2026-4122-Aravindkumar-AI-B-DS/blob/main/week-5/hypothesis_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#HYPOTHESIS TESTING

import math
n=100
x=60
p_hat=x/n
SE=math.sqrt(p_hat*(1-p_hat)/n)
#Confidence interval
z=1.96
lower=p_hat-z*SE
upper=p_hat+z*SE
print("Sample proportion:",p_hat)
print("Confidence Interval=",p_hat)
po=0.50
z_test=(p_hat-po)/math.sqrt(po*(1-po)/n)
print("Z-value:",z_test)
if abs(z_test)>1.96:
  print("Reject Ho")
else:
  print("Do not reject Ho")
# Out:
# Sample proportion: 0.6
# Confidence Interval= 0.6
# Z-value: 1.9999999999999996
# Reject Ho
