# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravindkumar-wp/2025-2026-4122-Aravindkumar-AI-B-DS/blob/main/Selection_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#selection sort

n=int(input("enter no.of elements:"))
arr=[]
for i in range(n):
  arr.append(int(input(f"enter elements{i+1}")))

print("\n Original array:",arr)
# selection sort logic
for i in range(n-1):

  min_index=i
  for j in range(i+1,n):
    if arr[j]<arr[min_index]:
      min_index=j
  #swap found min element with current element 'i'
  if min_index != i:
    arr[i],arr[min_index]=arr[min_index],arr[i]
print("\n Sorted array:",arr)
# Out:
# enter no.of elements:4
# enter elements190
# enter elements237
# enter elements32394
# enter elements442
#
#  Original array: [90, 37, 2394, 42]
#
#  Sorted array: [37, 42, 90, 2394]

# %%
#selection sort

n=int(input("enter no.of elements:"))
arr=[]
for i in range(n):
  arr.append(int(input(f"enter elements{i+1}:")))

print("\n Original array:",arr)
# selection sort logic
for i in range(n-1):

  min_index=i
  for j in range(i+1,n):
    if arr[j]<arr[min_index]:
      min_index=j
  #swap found min element with current element 'i'
  if min_index != i:
    arr[i],arr[min_index]=arr[min_index],arr[i]
print("\n Sorted array:",arr)
